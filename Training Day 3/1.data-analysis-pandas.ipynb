# %%
import pandas as pd

# %%
movie_df=pd.read_csv(r'C:\Users\winai\All Data\My AI Data\Training Day 3\Data\MovieRating.csv', index_col=0)
movie_df
# Out:
#                                                movie         year  rating  \
# 0                                              Logan       (2017)     8.1
# 1                                     Thor: Ragnarok       (2017)     7.9
# 2                     Guardians of the Galaxy Vol. 2       (2017)     7.6
# 3                                       Wonder Woman       (2017)     7.4
# 4                                            Dunkirk       (2017)     7.9
# 5            Star Wars: Episode VIII - The Last Jedi       (2017)     7.1
# 6                             Spider-Man: Homecoming       (2017)     7.5
# 7                                            Get Out   (I) (2017)     7.7
# 8                                  Blade Runner 2049       (2017)     8.0
# 9                                        Baby Driver       (2017)     7.6
# 10                                                It   (I) (2017)     7.4
# 11         Three Billboards Outside Ebbing, Missouri       (2017)     8.2
# ...

# %%
movie_df.dtypes
# Out:
# movie      object
# year       object
# rating    float64
# vote        int64
# dtype: object

# %%
movie_df.head()
# Out:
#                             movie    year  rating    vote
# 0                           Logan  (2017)     8.1  121002
# 1                  Thor: Ragnarok  (2017)     7.9  121002
# 2  Guardians of the Galaxy Vol. 2  (2017)     7.6  121002
# 3                    Wonder Woman  (2017)     7.4  121002
# 4                         Dunkirk  (2017)     7.9  121002

# %%
movie_df.describe()
# Out:
#           rating      vote
# count  50.000000      50.0
# mean    7.286000  121002.0
# std     0.839098       0.0
# min     5.200000  121002.0
# 25%     6.625000  121002.0
# 50%     7.400000  121002.0
# 75%     7.900000  121002.0
# max     8.700000  121002.0

# %%
movie_df['movie']
# Out:
# 0                                                Logan
# 1                                       Thor: Ragnarok
# 2                       Guardians of the Galaxy Vol. 2
# 3                                         Wonder Woman
# 4                                              Dunkirk
# 5              Star Wars: Episode VIII - The Last Jedi
# 6                               Spider-Man: Homecoming
# 7                                              Get Out
# 8                                    Blade Runner 2049
# 9                                          Baby Driver
# 10                                                  It
# 11           Three Billboards Outside Ebbing, Missouri
# 12                                      Justice League
# 13                                  The Shape of Water
# 14                                John Wick: Chapter 2
# 15                                                Coco
# 16                      Jumanji: Welcome to the Jungle
# ...

# %%
movie_df[['movie','rating']]
# Out:
#                                                movie  rating
# 0                                              Logan     8.1
# 1                                     Thor: Ragnarok     7.9
# 2                     Guardians of the Galaxy Vol. 2     7.6
# 3                                       Wonder Woman     7.4
# 4                                            Dunkirk     7.9
# 5            Star Wars: Episode VIII - The Last Jedi     7.1
# 6                             Spider-Man: Homecoming     7.5
# 7                                            Get Out     7.7
# 8                                  Blade Runner 2049     8.0
# 9                                        Baby Driver     7.6
# 10                                                It     7.4
# 11         Three Billboards Outside Ebbing, Missouri     8.2
# 12                                    Justice League     6.4
# 13                                The Shape of Water     7.3
# ...

# %%
movie_df['movie'][1]
# Out:
# 'Thor: Ragnarok'

# %%
movie_df['movie'][1:5]
# Out:
# 1                    Thor: Ragnarok
# 2    Guardians of the Galaxy Vol. 2
# 3                      Wonder Woman
# 4                           Dunkirk
# Name: movie, dtype: object

# %%
movie_df.loc[1, ['movie','vote']] #ชื่อ แถว กับ ชื่อ หลัก
# Out:
# movie    Thor: Ragnarok
# vote             121002
# Name: 1, dtype: object

# %%
movie_df.loc[[1,3]]
# Out:
#             movie    year  rating    vote
# 1  Thor: Ragnarok  (2017)     7.9  121002
# 3    Wonder Woman  (2017)     7.4  121002

# %%
movie_df.loc[1:10, ['movie','vote']]
# Out:
#                                       movie    vote
# 1                            Thor: Ragnarok  121002
# 2            Guardians of the Galaxy Vol. 2  121002
# 3                              Wonder Woman  121002
# 4                                   Dunkirk  121002
# 5   Star Wars: Episode VIII - The Last Jedi  121002
# 6                    Spider-Man: Homecoming  121002
# 7                                   Get Out  121002
# 8                         Blade Runner 2049  121002
# 9                               Baby Driver  121002
# 10                                       It  121002

# %%
movie_df.iloc[1:10,[0,3]]
# Out:
#                                      movie    vote
# 1                           Thor: Ragnarok  121002
# 2           Guardians of the Galaxy Vol. 2  121002
# 3                             Wonder Woman  121002
# 4                                  Dunkirk  121002
# 5  Star Wars: Episode VIII - The Last Jedi  121002
# 6                   Spider-Man: Homecoming  121002
# 7                                  Get Out  121002
# 8                        Blade Runner 2049  121002
# 9                              Baby Driver  121002

# %% [markdown]
# # Data Analyzing

# %%
movie_df['rating'].unique() # find unique data
# Out:
# array([8.1, 7.9, 7.6, 7.4, 7.1, 7.5, 7.7, 8. , 8.2, 6.4, 7.3, 8.4, 6.9,
#        7.2, 6.6, 6.8, 6.7, 6.5, 5.5, 8.6, 8.7, 8.5, 5.2])

# %%
movie_df['rating'].nunique() # number of unique data
# Out:
# 23

# %%
movie_df['rating'].value_counts() # data counting
# Out:
# rating
# 7.4    5
# 7.9    4
# 6.4    4
# 6.6    4
# 8.6    4
# 7.5    3
# 7.6    3
# 6.7    2
# 7.7    2
# 7.1    2
# 6.9    2
# 6.8    2
# 6.5    2
# 5.5    2
# 8.1    1
# 7.2    1
# 8.4    1
# 8.2    1
# 7.3    1
# 8.0    1
# 8.7    1
# 8.5    1
# 5.2    1
# Name: count, dtype: int64

# %% [markdown]
# # selecting data

# %%
newdf=movie_df[movie_df['rating']>8]

# %%
newdf
# Out:
#                                         movie         year  rating    vote
# 0                                       Logan       (2017)     8.1  121002
# 11  Three Billboards Outside Ebbing, Missouri       (2017)     8.2  121002
# 15                                       Coco   (I) (2017)     8.4  121002
# 36                           La Casa de Papel     (2017– )     8.6  121002
# 37                               The Punisher  (2017–2019)     8.6  121002
# 44                                       Dark     (2017– )     8.7  121002
# 45                                 Mindhunter     (2017– )     8.6  121002
# 47                        The Handmaid's Tale     (2017– )     8.5  121002
# 49                            Big Little Lies     (2017– )     8.6  121002

# %%
#rating < 8 และ >= 7
newdf=movie_df[(movie_df['rating']<8) & (movie_df['rating']>=7) ] #and

# %%
newdf
# Out:
#                                       movie        year  rating    vote
# 1                            Thor: Ragnarok      (2017)     7.9  121002
# 2            Guardians of the Galaxy Vol. 2      (2017)     7.6  121002
# 3                              Wonder Woman      (2017)     7.4  121002
# 4                                   Dunkirk      (2017)     7.9  121002
# 5   Star Wars: Episode VIII - The Last Jedi      (2017)     7.1  121002
# 6                    Spider-Man: Homecoming      (2017)     7.5  121002
# 7                                   Get Out  (I) (2017)     7.7  121002
# 9                               Baby Driver      (2017)     7.6  121002
# 10                                       It  (I) (2017)     7.4  121002
# 13                       The Shape of Water      (2017)     7.3  121002
# 14                     John Wick: Chapter 2      (2017)     7.5  121002
# 17                     Beauty and the Beast      (2017)     7.2  121002
# ...

# %%
#rating < 5 และ > 7
newdf=movie_df[(movie_df['rating']<5) & (movie_df['rating']>7) ] #and

# %%
newdf
# Out:
# Empty DataFrame
# Columns: [movie, year, rating, vote]
# Index: []

# %%
movie_df.columns
# Out:
# Index(['movie', 'year', 'rating', 'vote'], dtype='object')

# %% [markdown]
# # function

# %%
movie_df['vote'].sum()
# Out:
# np.int64(6050100)

# %%
movie_df['rating'].mean()
# Out:
# np.float64(7.2860000000000005)

# %%
movie_df['rating'].std()
# Out:
# np.float64(0.8390981553344722)

# %%
movie_df.sort_values(by='rating')
# Out:
#                                                movie         year  rating  \
# 48                     Transformers: The Last Knight       (2017)     5.2
# 35                                         The Mummy       (2017)     5.5
# 42                                          Baywatch       (2017)     5.5
# 12                                    Justice League       (2017)     6.4
# 39                                            Bright   (I) (2017)     6.4
# 21                                   Alien: Covenant       (2017)     6.4
# 29                                Ghost in the Shell       (2017)     6.4
# 28                      Murder on the Orient Express       (2017)     6.5
# 41       Valerian and the City of a Thousand Planets       (2017)     6.5
# 18                                Kong: Skull Island       (2017)     6.6
# 33                                           Mother!       (2017)     6.6
# 20  Pirates of the Caribbean: Dead Men Tell No Tales       (2017)     6.6
# ...

# %%
movie_df.sort_values(by='rating', ascending=False)
# Out:
#                                                movie         year  rating  \
# 44                                              Dark     (2017– )     8.7
# 36                                  La Casa de Papel     (2017– )     8.6
# 45                                        Mindhunter     (2017– )     8.6
# 37                                      The Punisher  (2017–2019)     8.6
# 49                                   Big Little Lies     (2017– )     8.6
# 47                               The Handmaid's Tale     (2017– )     8.5
# 15                                              Coco   (I) (2017)     8.4
# 11         Three Billboards Outside Ebbing, Missouri       (2017)     8.2
# 0                                              Logan       (2017)     8.1
# 8                                  Blade Runner 2049       (2017)     8.0
# 34                              Call Me by Your Name       (2017)     7.9
# 22                                    13 Reasons Why     (2017– )     7.9
# ...

# %%
movie_df['movie'].str.contains('L')
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25     True
# 26    False
# 27     True
# 28    False
# 29    False
# 30    False
# 31     True
# 32    False
# 33    False
# 34    False
# 35    False
# 36     True
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48     True
# 49     True
# Name: movie, dtype: bool

# %%
movie_df[movie_df['movie'].str.contains('L')]
# Out:
#                                       movie        year  rating    vote
# 0                                     Logan      (2017)     8.1  121002
# 5   Star Wars: Episode VIII - The Last Jedi      (2017)     7.1  121002
# 12                           Justice League      (2017)     6.4  121002
# 25                                     Life  (I) (2017)     6.6  121002
# 27                                Lady Bird      (2017)     7.4  121002
# 31         King Arthur: Legend of the Sword      (2017)     6.8  121002
# 36                         La Casa de Papel    (2017– )     8.6  121002
# 48            Transformers: The Last Knight      (2017)     5.2  121002
# 49                          Big Little Lies    (2017– )     8.6  121002

# %%
movie_df['movie'][0]
# Out:
# 'Logan'

# %%
movie_df['movie'][0].lower()
# Out:
# 'logan'

# %%
movie_df['movie'].map(lambda x: x.lower())
# Out:
# 0                                                logan
# 1                                       thor: ragnarok
# 2                       guardians of the galaxy vol. 2
# 3                                         wonder woman
# 4                                              dunkirk
# 5              star wars: episode viii - the last jedi
# 6                               spider-man: homecoming
# 7                                              get out
# 8                                    blade runner 2049
# 9                                          baby driver
# 10                                                  it
# 11           three billboards outside ebbing, missouri
# 12                                      justice league
# 13                                  the shape of water
# 14                                john wick: chapter 2
# 15                                                coco
# 16                      jumanji: welcome to the jungle
# ...

# %%
#ตัวอักษรแรกของชื่อหนัง
movie_df['movie'].map(lambda x: x[0])
# Out:
# 0     L
# 1     T
# 2     G
# 3     W
# 4     D
# 5     S
# 6     S
# 7     G
# 8     B
# 9     B
# 10    I
# 11    T
# 12    J
# 13    T
# 14    J
# 15    C
# 16    J
# 17    B
# 18    K
# 19    K
# 20    P
# 21    A
# 22    1
# 23    W
# 24    T
# 25    L
# 26    T
# 27    L
# 28    M
# 29    G
# 30    W
# 31    K
# 32    T
# 33    M
# 34    C
# 35    T
# 36    L
# 37    T
# 38    A
# 39    B
# 40    I
# 41    V
# 42    B
# 43    D
# 44    D
# 45    M
# 46    A
# 47    T
# 48    T
# 49    B
# Name: movie, dtype: object

# %% [markdown]
# # Missing Data

# %%
df=pd.DataFrame({'A':[1,2,None],
                 'B':[5,None,None],
                 'C':[1,2,3]})

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna() #drop แถว
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1) #drop หลัก
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna(thresh=2, axis=1)
# Out:
#      A  C
# 0  1.0  1
# 1  2.0  2
# 2  NaN  3

# %%
df.fillna(value='Fill')
# Out:
#       A     B  C
# 0   1.0   5.0  1
# 1   2.0  Fill  2
# 2  Fill  Fill  3

# %%
df['A'].mean()
# Out:
# np.float64(1.5)

# %%
df['A']=df['A'].fillna(value=df['A'].mean()) #เติมค่าเฉลี่ยนใน na

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  1.5  NaN  3

# %% [markdown]
# # data visualization

# %%
movie_df.head()
# Out:
#                             movie    year  rating    vote
# 0                           Logan  (2017)     8.1  121002
# 1                  Thor: Ragnarok  (2017)     7.9  121002
# 2  Guardians of the Galaxy Vol. 2  (2017)     7.6  121002
# 3                    Wonder Woman  (2017)     7.4  121002
# 4                         Dunkirk  (2017)     7.9  121002

# %%
movie_df['rating'].hist(bins=20)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.style.use('bmh')

# %%
movie_df['rating'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('dark_background')
movie_df['rating'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('ggplot')
movie_df['rating'].hist()
# Out:
# <Axes: >
